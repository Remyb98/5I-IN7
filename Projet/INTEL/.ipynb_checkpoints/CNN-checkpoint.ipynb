# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sn
import pandas as pd

# %%
train_path = "dataset/seg_train/seg_train"
test_path = "dataset/seg_test/seg_test"

classes = os.listdir(train_path)
print(classes)
classes_dir = {'buildings': 0, 'forest': 1, 'glacier': 2, 'mountain': 3, 'sea': 4, 'street': 5}
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %% [markdown]
# ### Load Data

# %%
# TRAIN IMAGES
nb_train_images = 0
for dir in classes:
    nb_train_images += len(os.listdir(os.path.join(train_path, dir)))
print("Train images : " + str(nb_train_images))

train_images_x = []
train_images_y = []

for dir in classes:
    for filename in os.listdir(os.path.join(train_path, dir)):
        image = cv2.imread(os.path.join(train_path, dir, filename))
        image = cv2.resize(image, dsize = (150, 150))
        train_images_x.append(image)
        train_images_y.append(classes_dir[dir])

train_images_x = np.array(train_images_x)
train_images_y = np.array(train_images_y)

# TEST IMAGES
nb_test_images = 0
for dir in classes:
    nb_test_images += len(os.listdir(os.path.join(test_path, dir)))
print("Test images : " + str(nb_test_images))

test_images_x = []
test_images_y = []

for dir in classes:
    for filename in os.listdir(os.path.join(test_path, dir)):
        image = cv2.imread(os.path.join(test_path, dir, filename))
        image = cv2.resize(image, dsize = (150, 150))
        test_images_x.append(image)
        test_images_y.append(classes_dir[dir])
    
test_images_x = np.array(test_images_x)
test_images_y = np.array(test_images_y)
# Out:
# Train images : 14034
# Test images : 3000

# %% [markdown]
# ### Display dataset

# %%
# TRAIN IMAGES
import random

print("Train images :")

fig, axs = plt.subplots(1, 3, figsize = (15, 15))

for i, ax in enumerate(axs.flat):
    i = random.randint(0, nb_train_images-1)
    ax.imshow(train_images_x[i])
    ax.axis('off')
    ax.set_title(train_images_y[i])

plt.show()

# TEST IMAGES
print("Test images")

fig, axs = plt.subplots(1, 3, figsize = (15, 15))

for i, ax in enumerate(axs.flat):
    i = random.randint(0, nb_test_images-1)
    ax.imshow(test_images_x[i])
    ax.axis('off')
    ax.set_title(test_images_y[i])

plt.show()
# Out:
# Train images :
# Test images

# %% [markdown]
# ## Model

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout

# %% [markdown]
# ### Initialisation CNN

# %%
# Init CNN
classifier = tf.keras.Sequential()

classifier.add(tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu', input_shape=(150, 150, 3)))
classifier.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
classifier.add(tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'))
classifier.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
classifier.add(tf.keras.layers.Flatten())
classifier.add(tf.keras.layers.Dense(128, activation='relu'))
classifier.add(tf.keras.layers.Dense(6, activation='softmax')) # Number of possible outcome
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Normalisation

# %%
train_images_x = train_images_x / 255.0

# %% [markdown]
# ### Entrainement

# %%
train_images_x = np.array(train_images_x)
train_images_y = np.array(train_images_y)
test_images_x = np.array(test_images_x)
test_images_y = np.array(test_images_y)

history = classifier.fit(train_images_x, 
                         train_images_y,
                         validation_data=(test_images_x, test_images_y),
                         epochs=20)
# Out:
# Epoch 1/20
# 439/439 [==============================] - 14s 17ms/step - loss: 0.9112 - accuracy: 0.6606 - val_loss: 166.0838 - val_accuracy: 0.6343
# Epoch 2/20
# 439/439 [==============================] - 9s 19ms/step - loss: 0.5725 - accuracy: 0.7942 - val_loss: 138.4559 - val_accuracy: 0.6897
# Epoch 3/20
# 439/439 [==============================] - 8s 19ms/step - loss: 0.3599 - accuracy: 0.8741 - val_loss: 206.9142 - val_accuracy: 0.6867
# Epoch 4/20
# 439/439 [==============================] - 8s 19ms/step - loss: 0.1979 - accuracy: 0.9339 - val_loss: 226.4890 - val_accuracy: 0.6990
# Epoch 5/20
# 439/439 [==============================] - 8s 19ms/step - loss: 0.0991 - accuracy: 0.9689 - val_loss: 307.8829 - val_accuracy: 0.6860
# Epoch 6/20
# 439/439 [==============================] - 9s 20ms/step - loss: 0.0637 - accuracy: 0.9805 - val_loss: 210.2286 - val_accuracy: 0.7377
# Epoch 7/20
# 439/439 [==============================] - 8s 19ms/step - loss: 0.0567 - accuracy: 0.9853 - val_loss: 369.3395 - val_accuracy: 0.6863
# Epoch 8/20
# 439/439 [==============================] - 8s 19ms/step - loss: 0.0397 - accuracy: 0.9900 - val_loss: 315.4327 - val_accuracy: 0.7437
# Epoch 9/20
# 439/439 [==============================] - 9s 20ms/step - loss: 0.0391 - accuracy: 0.9899 - val_loss: 364.4042 - val_accuracy: 0.7123
# Epoch 10/20
# 439/439 [==============================] - 8s 18ms/step - loss: 0.0372 - accuracy: 0.9921 - val_loss: 418.3409 - val_accuracy: 0.6817
# Epoch 11/20
# 439/439 [==============================] - 7s 16ms/step - loss: 0.0291 - accuracy: 0.9927 - val_loss: 496.4266 - val_accuracy: 0.6910
# Epoch 12/20
# 439/439 [==============================] - 7s 17ms/step - loss: 0.0511 - accuracy: 0.9866 - val_loss: 349.2576 - val_accuracy: 0.7257
# Epoch 13/20
# 439/439 [==============================] - 10s 22ms/step - loss: 0.0353 - accuracy: 0.9904 - val_loss: 435.8531 - val_accuracy: 0.6977
# Epoch 14/20
# 439/439 [==============================] - 10s 22ms/step - loss: 0.0288 - accuracy: 0.9919 - val_loss: 482.0829 - val_accuracy: 0.6953
# Epoch 15/20
# 439/439 [==============================] - 9s 21ms/step - loss: 0.0308 - accuracy: 0.9928 - val_loss: 358.7478 - val_accuracy: 0.7620
# Epoch 16/20
# 439/439 [==============================] - 10s 22ms/step - loss: 0.0229 - accuracy: 0.9939 - val_loss: 350.2734 - val_accuracy: 0.7530
# Epoch 17/20
# 439/439 [==============================] - 9s 21ms/step - loss: 0.0185 - accuracy: 0.9951 - val_loss: 439.7815 - val_accuracy: 0.7307
# Epoch 18/20
# 439/439 [==============================] - 9s 21ms/step - loss: 0.0139 - accuracy: 0.9968 - val_loss: 392.5500 - val_accuracy: 0.7397
# Epoch 19/20
# 439/439 [==============================] - 10s 22ms/step - loss: 0.0073 - accuracy: 0.9986 - val_loss: 440.8629 - val_accuracy: 0.7273
# Epoch 20/20
# 439/439 [==============================] - 9s 21ms/step - loss: 0.0094 - accuracy: 0.9984 - val_loss: 421.1265 - val_accuracy: 0.7390

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model accuracy")
plt.legend(["accuracy", "val_accuracy"])
plt.xlabel("accuracy")
plt.ylabel("epoch")
plt.grid()
plt.show()

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model loss")
plt.legend(["loss", "val_loss"])
plt.xlabel("loss")
plt.ylabel("epoch")
plt.grid()
plt.show()

# %% [markdown]
# ### Predictions

# %%
pred_classes = np.argmax(classifier.predict(test_images_x), axis=1)
print("Score de précision : " + str(round(accuracy_score(test_images_y, pred_classes), 4)))
cm = confusion_matrix(test_images_y, pred_classes) 
df = pd.DataFrame(cm, classes_dir.keys(), classes_dir.keys())
plt.figure(figsize=(15, 15))
sn.heatmap(df, annot=True)
plt.show()
# Out:
# Score de précision : 0.739
